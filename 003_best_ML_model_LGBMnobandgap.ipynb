# %% [markdown]
# ## Best ML Model

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import lightgbm as lgb

# %%
data = pd.read_csv('regression/final_elem_SP.csv')
data.head()
# Out:
#   formula         S_p   Bandgap       mpe        PF   X_b    std_BL   mean_BL  \
# 0    ReO3    0.336845  0.000000  0.311128  0.276212  3.44  0.000001  1.913169
# 1   Yb3Mg   14.406792  0.000000  0.740480  0.573238  1.31  0.000000  3.690337
# 2   B9H11  638.974583  2.911795  0.101052  0.125865  2.20  0.059786  1.236931
# 3  Li3Ga7    9.061345  0.000000  0.542895  0.555130  1.81  0.073217  2.838474
# 4   Sc3Cd   22.887388  0.000000  0.713049  0.719525  1.69  0.004315  3.206197
#
#    vdw_r_b  Mean_NpValence  ...  Mean_NfUnfilled       AM_b    MP_b  \
# 0     1.52            3.00  ...              0.0   15.99940   54.80
# 1     1.73            0.00  ...              0.0   24.30500  923.00
# 2     1.10            0.45  ...              0.0    1.00794   14.01
# 3     1.87            0.70  ...              0.0   69.72300  302.91
# 4     2.18            0.00  ...              0.0  112.41100  594.22
#
#    Mean_NsUnfilled  Mean_NsValence  MeanColumn  MEN_V_b  Mean_NdUnfilled  \
# 0             0.00            2.00       13.75     14.0             1.25
# 1             0.00            2.00        2.75     14.0             0.00
# 2             0.55            1.45        6.40     14.1             0.00
# 3             0.30            1.70        9.40     11.8             0.00
# 4             0.00            2.00        5.25     13.1             6.75
#
#         TC_b       D_b
# 0    0.02658  0.001308
# 1  160.00000  1.740000
# 2    0.18050  0.000082
# 3   29.00000  5.910000
# 4   97.00000  8.690000
#
# [5 rows x 50 columns]

# %%
data = data.drop(['Bandgap','TC_a','D_a','MEN_V_a','Mean_NfValence','EA_b','r_a',
'Mean_NdValence','r_b','Mean_GSbandgap','Number','Mean_GSmagmom','Mean_NfUnfilled',
'AM_b','MP_b','Mean_NsUnfilled','Mean_NsValence','MeanColumn','MEN_V_b',
'Mean_NdUnfilled','TC_b','D_b'], axis=1)

# %%
X = data.iloc[:,2:-1]
Y = data.iloc[:,1]

# %%
def read_param():  ## function for reading saved hyperparameters
    f0 = open('regression/best-paramters_lgb_optuna_TPE_plot_SP_NOBANDGAP.txt','r')
    b = []
    for line in f0.readlines():
        a = line.split()
        a_ = [a[i] for i in range(len(a))]
        b.append(a_)
    f0.close()
    p1 = float(b[1][1]); p2 = float(b[2][1]); p3 = int(b[3][1]); p4 = float(b[4][1])
    p5 = float(b[5][1]); p6 = int(b[6][1]); p7 = int(b[7][1]); p8 = float(b[8][1])
#     p9 = int(b[9][1])
    return p1, p2, p3, p4, p5, p6, p7, p8

# %%
R2test = []
R2train = []
rmsetest = []
rmsetrain = []
maetest = []
maetrain = []


p1, p2, p3, p4, p5, p6, p7, p8 = read_param()
params = {'objective': 'regression', 'boosting_type': 'gbdt', 'lambda_l1': p1,
          'lambda_l2': p2, 'num_leaves': p3, 'feature_fraction': p4, 
          'bagging_fraction': p5, 'bagging_freq': p6, 'min_child_samples': p7,
          'learning_rate': p8}

# %% [markdown]
# ## Finding the best ML model

# %%
start = 0
end = 2000
test_size = 0.3
for random in range(start, end+1, 1):
    print(random)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, 
                                                      test_size = test_size, random_state = random)
    d_train = lgb.Dataset(X_train, label = Y_train)                  
    reg = lgb.train(params, d_train)
    
    Y_pred_test = reg.predict(X_test) 
    Y_pred_train = reg.predict(X_train) 
    
    R2_test = r2_score(Y_test, Y_pred_test)
    R2_train = r2_score(Y_train, Y_pred_train)
    print("R2 value train:  ", R2_train)
    print("R2 value test:  ", R2_test)
       
    rmse_test=np.sqrt(mean_squared_error(Y_test, Y_pred_test))
    rmse_train=np.sqrt(mean_squared_error(Y_train, Y_pred_train))
    print("RMSE train:  ", rmse_train)
    print("RMSE test:  ",  rmse_test)
    
    mae_test=mean_absolute_error(Y_test, Y_pred_test)
    mae_train=mean_absolute_error(Y_train, Y_pred_train)
    print("mae train:  ", mae_train)
    print("mae test:  ",  mae_test)


    R2test.append(R2_test)
    R2train.append(R2_train)
    rmsetest.append(rmse_test)
    rmsetrain.append(rmse_train)
    maetest.append(mae_test)
    maetrain.append(mae_train)
# Out:
# 0
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001202 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4424
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.024342
# R2 value train:   0.9567231879093232
# R2 value test:   0.7725877180908525
# RMSE train:   63.921119022016946
# RMSE test:   146.8388799652001
# mae train:   35.442695950054336
# mae test:   76.14324488834424
# 1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001631 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4394
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 216.191219
# R2 value train:   0.9567883597873679
# R2 value test:   0.7845801027342745
# RMSE train:   64.19946341618459
# RMSE test:   141.0542146651257
# mae train:   36.12775496191646
# mae test:   75.54577594883429
# 2
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000997 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4447
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.690986
# R2 value train:   0.9616996948485446
# R2 value test:   0.7636909615757207
# RMSE train:   59.89517019971249
# RMSE test:   150.99087174645373
# mae train:   33.75763951152322
# mae test:   81.33184790495979
# 3
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000893 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4391
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.561778
# R2 value train:   0.9583980793902924
# R2 value test:   0.7835980613406786
# RMSE train:   62.795682345752994
# RMSE test:   142.58628747029965
# mae train:   35.60653001303275
# mae test:   74.59226135402527
# 4
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000842 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4393
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.335775
# R2 value train:   0.9602083729888483
# R2 value test:   0.7584180320943043
# RMSE train:   61.03541667582461
# RMSE test:   152.73387365367566
# mae train:   34.042588317540094
# mae test:   79.84072056496883
# 5
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000809 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4397
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.048326
# R2 value train:   0.9572334564464813
# R2 value test:   0.7872238607957038
# RMSE train:   63.65835104375743
# RMSE test:   141.43550119079032
# mae train:   35.64667943733726
# mae test:   74.48763356064127
# 6
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000769 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4402
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.315601
# R2 value train:   0.958326374182383
# R2 value test:   0.7718821023799329
# RMSE train:   62.80646580669788
# RMSE test:   146.63037805445373
# mae train:   34.8838916047257
# mae test:   78.31421701495731
# 7
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4395
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.884628
# R2 value train:   0.9568618361827227
# R2 value test:   0.7873858649505131
# RMSE train:   63.70460483664473
# RMSE test:   142.57464980542554
# mae train:   35.6412182521079
# mae test:   76.38992723699798
# 8
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000820 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4418
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.462699
# R2 value train:   0.9562237053652481
# R2 value test:   0.7877390656025156
# RMSE train:   64.15326515012893
# RMSE test:   142.52293249910446
# mae train:   36.06593601618035
# mae test:   76.34914843847267
# 9
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000875 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4407
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.434659
# R2 value train:   0.956445817425328
# R2 value test:   0.7674096247662611
# RMSE train:   64.19584022524784
# RMSE test:   148.1181700167453
# mae train:   35.57127623040744
# mae test:   77.47880347113828
# 10
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000817 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4453
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 216.965744
# R2 value train:   0.9575024135750854
# R2 value test:   0.778074974354792
# RMSE train:   64.00110052491202
# RMSE test:   141.2889173973439
# mae train:   35.83376862636786
# mae test:   73.97666813371755
# 11
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000715 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4406
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 215.050062
# R2 value train:   0.9585231656654416
# R2 value test:   0.7812711866604343
# RMSE train:   62.974714536541015
# RMSE test:   141.7748700164024
# mae train:   35.16377685922442
# mae test:   74.17733041595089
# 12
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000829 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4416
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 215.919276
# R2 value train:   0.9562587428031647
# R2 value test:   0.7696735588875211
# RMSE train:   64.69137060766764
# RMSE test:   145.3259880284454
# mae train:   36.53608418779543
# mae test:   75.73743955539861
# 13
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000931 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4405
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.202329
# R2 value train:   0.957037074986006
# R2 value test:   0.7787536966177292
# RMSE train:   63.95858160826818
# RMSE test:   143.40632219555977
# mae train:   36.17816655149999
# mae test:   75.21538309490532
# 14
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001129 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4410
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.826859
# R2 value train:   0.9581641363368489
# R2 value test:   0.7870776181969041
# RMSE train:   62.95129901484831
# RMSE test:   141.54270854854917
# mae train:   35.21679057438013
# mae test:   73.55315361371697
# 15
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000482 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4407
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 205.667043
# R2 value train:   0.9569271756639212
# R2 value test:   0.7867187417610333
# RMSE train:   63.38295783295855
# RMSE test:   144.02818271353308
# mae train:   35.46796792184107
# mae test:   75.5775258363598
# 16
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4401
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.057085
# R2 value train:   0.9555939511901048
# R2 value test:   0.8068324027182975
# RMSE train:   64.90562748352866
# RMSE test:   134.5783422337743
# mae train:   36.67424711462196
# mae test:   72.60413603303604
# 17
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 214.877075
# R2 value train:   0.9576623706881215
# R2 value test:   0.7799357994504744
# RMSE train:   63.718687287145464
# RMSE test:   141.70474657550824
# mae train:   35.92673540085736
# mae test:   72.7761369733661
# 18
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000790 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4449
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.753190
# R2 value train:   0.9603683621702329
# R2 value test:   0.7858923988697569
# RMSE train:   61.063376510859214
# RMSE test:   143.0591572680275
# mae train:   34.45054328058382
# mae test:   75.98694704600518
# 19
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4382
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 205.492853
# R2 value train:   0.9590614811096196
# R2 value test:   0.7740032333551679
# RMSE train:   61.675976910815685
# RMSE test:   148.87242037463554
# mae train:   34.5274464891806
# mae test:   78.84899081556563
# 20
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000881 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4406
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.850421
# R2 value train:   0.958155651366562
# R2 value test:   0.775112432939047
# RMSE train:   62.878746024436865
# RMSE test:   145.89588239992247
# mae train:   35.32757657537819
# mae test:   77.41852439947586
# 21
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4399
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.530262
# R2 value train:   0.9585490816869225
# R2 value test:   0.7739230098491638
# RMSE train:   62.67839905499822
# RMSE test:   145.75663163180263
# mae train:   34.99044992096247
# mae test:   76.42594654562923
# 22
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000819 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4407
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.452860
# R2 value train:   0.9580696389951981
# R2 value test:   0.791694951827526
# RMSE train:   62.47464112785343
# RMSE test:   142.74499041494772
# mae train:   34.89678306975219
# mae test:   75.42060761222724
# 23
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004475 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4413
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.493116
# R2 value train:   0.9634197801725658
# R2 value test:   0.74833961359405
# RMSE train:   58.89119554932474
# RMSE test:   153.71927604501107
# mae train:   32.643207681842824
# mae test:   82.17858342314308
# 24
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000583 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4404
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 206.361707
# R2 value train:   0.9610242195466084
# R2 value test:   0.7644912085621575
# RMSE train:   59.98949320102621
# RMSE test:   153.0807190125768
# mae train:   33.84305311315991
# mae test:   82.93872632175375
# 25
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000784 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4412
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 213.807588
# R2 value train:   0.9570075409596177
# R2 value test:   0.7514142780630773
# RMSE train:   64.02854842973804
# RMSE test:   151.6882825814709
# mae train:   35.76540703411216
# mae test:   78.39924649134862
# 26
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000870 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4401
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 215.566166
# R2 value train:   0.9580467481798524
# R2 value test:   0.7660227412890851
# RMSE train:   63.433182618889894
# RMSE test:   146.05509326030898
# mae train:   35.94138723589215
# mae test:   76.50514570424109
# 27
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4415
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.352134
# R2 value train:   0.9593900375645253
# R2 value test:   0.7724875499258566
# RMSE train:   61.79554077809982
# RMSE test:   147.5185400364879
# mae train:   34.32517222322574
# mae test:   79.09690286861857
# 28
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000547 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4399
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.747040
# R2 value train:   0.9553640395614799
# R2 value test:   0.7927241019554
# RMSE train:   65.04259726174341
# RMSE test:   139.55945012020084
# mae train:   36.4755589035737
# mae test:   73.22402943839606
# 29
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000878 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4390
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.039349
# R2 value train:   0.9596003930785981
# R2 value test:   0.7689863250352941
# RMSE train:   61.75463326364426
# RMSE test:   148.0255020868853
# mae train:   34.54377602822193
# mae test:   79.2091437444571
# 30
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000862 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4461
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 215.015503
# R2 value train:   0.954957315015655
# R2 value test:   0.783323499849881
# RMSE train:   65.58155523588763
# RMSE test:   141.34115630624967
# mae train:   36.99162488306651
# mae test:   73.66846979866412
# 31
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000859 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4404
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.191497
# R2 value train:   0.9576703321037106
# R2 value test:   0.7801334403926278
# RMSE train:   63.12299300896601
# RMSE test:   144.89008036710845
# mae train:   35.538983113948994
# mae test:   76.69043906761455
# 32
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000562 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4403
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.435028
# R2 value train:   0.9597621167540429
# R2 value test:   0.7714263708812724
# RMSE train:   61.916415690126335
# RMSE test:   145.65155710719046
# mae train:   34.50720321861274
# mae test:   76.23385069500726
# 33
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000889 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4395
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.019931
# R2 value train:   0.959257140562552
# R2 value test:   0.7701043684405664
# RMSE train:   61.66203253102084
# RMSE test:   149.55821475085676
# mae train:   34.45976752899565
# mae test:   77.59092090033597
# 34
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000798 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4409
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.577611
# R2 value train:   0.9559576327520405
# R2 value test:   0.7937918047409751
# RMSE train:   64.60006985352676
# RMSE test:   139.23264254491704
# mae train:   36.02640643811466
# mae test:   72.72679952878678
# 35
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001073 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4447
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.893956
# R2 value train:   0.9565529620913261
# R2 value test:   0.8027573270728328
# RMSE train:   63.89913254918564
# RMSE test:   137.46107839499024
# mae train:   35.84754179461941
# mae test:   72.47396916830887
# 36
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4412
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.643069
# R2 value train:   0.9561120369822149
# R2 value test:   0.7890940123711937
# RMSE train:   64.4606554626486
# RMSE test:   140.95564725307588
# mae train:   35.93898637744434
# mae test:   75.7849927611322
# 37
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000548 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4419
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 206.223887
# R2 value train:   0.9589953088080317
# R2 value test:   0.7764555934155826
# RMSE train:   61.76517494421386
# RMSE test:   147.89831349277898
# mae train:   34.249183100578485
# mae test:   78.4515877540938
# 38
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000524 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4413
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.590555
# R2 value train:   0.9579184256240733
# R2 value test:   0.7839818508375653
# RMSE train:   62.94925057701097
# RMSE test:   143.52018486039478
# mae train:   35.07062737447691
# mae test:   74.64323859150868
# 39
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000959 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4392
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.131850
# R2 value train:   0.9562205531560295
# R2 value test:   0.7872351103573257
# RMSE train:   64.11101901179035
# RMSE test:   142.93644226952992
# mae train:   35.997368936786
# mae test:   76.32288210726652
# 40
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000806 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4401
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 206.842280
# R2 value train:   0.9572166867223971
# R2 value test:   0.7819403352818975
# RMSE train:   63.124879841588836
# RMSE test:   145.9286803449684
# mae train:   34.86082474657766
# mae test:   78.93006082866559
# 41
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000802 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4393
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.275135
# R2 value train:   0.9573254870407093
# R2 value test:   0.7564170841998283
# RMSE train:   63.48690709917503
# RMSE test:   151.90514803069172
# mae train:   35.29104837427682
# mae test:   82.12817077238081
# 42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000794 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4404
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.508986
# R2 value train:   0.9551991510442934
# R2 value test:   0.8059887388140992
# RMSE train:   65.08129580128806
# RMSE test:   135.41651045172785
# mae train:   36.185220222501925
# mae test:   72.02151788464772
# 43
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000989 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4405
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.483096
# R2 value train:   0.9572116699761927
# R2 value test:   0.7851034589846487
# RMSE train:   63.423575825577956
# RMSE test:   143.43843768277742
# mae train:   35.26041910375674
# mae test:   75.29462183666185
# 44
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000489 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4394
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.212512
# R2 value train:   0.9602200190488761
# R2 value test:   0.7691581746671152
# RMSE train:   61.16551956944438
# RMSE test:   148.5914413107861
# mae train:   33.97748097015097
# mae test:   79.37913075664575
# 45
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000764 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4405
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 206.708727
# R2 value train:   0.9571702706673113
# R2 value test:   0.7931134621890608
# RMSE train:   63.31401704655278
# RMSE test:   141.35578953720656
# mae train:   35.3230354199295
# mae test:   75.13720017892942
# 46
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000607 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4409
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 215.300154
# R2 value train:   0.9580565006594455
# R2 value test:   0.7798785666191422
# RMSE train:   63.39118893957299
# RMSE test:   141.86806814782608
# mae train:   35.55970198663488
# mae test:   76.42400461719646
# 47
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000779 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4415
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.630340
# R2 value train:   0.9599818327584356
# R2 value test:   0.7647658462516964
# RMSE train:   61.24491469085467
# RMSE test:   150.5853002921832
# mae train:   34.25849648553214
# mae test:   77.77726338533354
# 48
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000493 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4410
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.028891
# R2 value train:   0.9559200318843578
# R2 value test:   0.7945238309607034
# RMSE train:   64.22264692719568
# RMSE test:   141.01844274873952
# mae train:   35.68803825356485
# mae test:   74.22880014795697
# 49
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000768 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4395
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.893631
# R2 value train:   0.9567712555164837
# R2 value test:   0.771653659560621
# RMSE train:   64.04063106982343
# RMSE test:   146.2939048463804
# mae train:   35.75407948776138
# mae test:   78.25097970830993
# 50
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000531 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4422
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 213.004966
# R2 value train:   0.9574343586847262
# R2 value test:   0.7826749509986821
# RMSE train:   63.67819474540317
# RMSE test:   142.0221589739656
# mae train:   35.84919698305267
# mae test:   75.79193515110157
# 51
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000839 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4390
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.015307
# R2 value train:   0.9553055105302909
# R2 value test:   0.7894279244979839
# RMSE train:   64.57683243280754
# RMSE test:   143.16587027830275
# mae train:   35.93385739846663
# mae test:   76.41519101630057
# 52
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000617 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4426
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.128788
# R2 value train:   0.9548021639856216
# R2 value test:   0.8030307110776945
# RMSE train:   65.4993683152357
# RMSE test:   135.8034066614917
# mae train:   36.562328385235176
# mae test:   71.62853452272113
# 53
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000554 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4414
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 213.359295
# R2 value train:   0.9569560545146629
# R2 value test:   0.7769256596383997
# RMSE train:   64.1798653330983
# RMSE test:   143.0968967967799
# mae train:   35.53743825920799
# mae test:   75.9854831793883
# 54
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4402
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.712933
# R2 value train:   0.9588721450027529
# R2 value test:   0.7635639251842423
# RMSE train:   62.5139375518873
# RMSE test:   148.60553346022706
# mae train:   35.0678061473938
# mae test:   76.53893813866198
# 55
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000525 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4399
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.238855
# R2 value train:   0.9587136549077131
# R2 value test:   0.7602892720444712
# RMSE train:   62.24289657447952
# RMSE test:   151.82502493795545
# mae train:   34.49515153282797
# mae test:   80.69775360048811
# 56
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000517 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4402
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.955453
# R2 value train:   0.9583560067906491
# R2 value test:   0.7883847054802022
# RMSE train:   62.471392595975736
# RMSE test:   142.80881723963645
# mae train:   34.75250856834004
# mae test:   74.91853659309373
# 57
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000907 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4394
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.501737
# R2 value train:   0.9583536436098167
# R2 value test:   0.772375796635672
# RMSE train:   62.88839572909253
# RMSE test:   145.91153490099657
# mae train:   34.73779662041862
# mae test:   78.24499688998422
# 58
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000649 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4407
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.947738
# R2 value train:   0.9529147611064014
# R2 value test:   0.7998991310965904
# RMSE train:   66.83418089094587
# RMSE test:   136.97160276898174
# mae train:   37.526935565760716
# mae test:   70.84412722361944
# 59
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000863 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.365303
# R2 value train:   0.9562653439237445
# R2 value test:   0.7808656960800541
# RMSE train:   64.37771099692692
# RMSE test:   143.5237465791844
# mae train:   36.073840491740874
# mae test:   76.94053459075887
# 60
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000532 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.560727
# R2 value train:   0.9572318250572495
# R2 value test:   0.7718802594024693
# RMSE train:   63.6606079717644
# RMSE test:   146.44550693845343
# mae train:   35.61545467782661
# mae test:   76.99643301655132
# 61
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4409
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.047528
# R2 value train:   0.9607533412509818
# R2 value test:   0.7531035138687732
# RMSE train:   61.23281658479223
# RMSE test:   150.87385021328032
# mae train:   34.20069661033734
# mae test:   78.1200507949179
# 62
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4401
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.501333
# R2 value train:   0.9572868367570322
# R2 value test:   0.7776602230866578
# RMSE train:   63.63341899705127
# RMSE test:   144.50507715321154
# mae train:   35.617901807625906
# mae test:   76.26120877274344
# 63
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000785 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4412
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.464957
# R2 value train:   0.9577169735278293
# R2 value test:   0.795068395095545
# RMSE train:   62.86785779596773
# RMSE test:   140.96137120079769
# mae train:   35.154867363466614
# mae test:   75.42303360071422
# 64
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000865 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4454
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.310755
# R2 value train:   0.9578683868093242
# R2 value test:   0.7621994339097766
# RMSE train:   62.94936443935707
# RMSE test:   150.82176917545485
# mae train:   34.835111041762275
# mae test:   79.33418301809378
# 65
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000573 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4421
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.192767
# R2 value train:   0.9573531022860758
# R2 value test:   0.794849115275278
# RMSE train:   63.13004400117201
# RMSE test:   141.10963371694984
# mae train:   35.43705371824806
# mae test:   74.95649364354992
# 66
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001440 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4387
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.278525
# R2 value train:   0.9579558223239166
# R2 value test:   0.7845723090940819
# RMSE train:   62.6683528099227
# RMSE test:   144.6326949407161
# mae train:   35.045923094571336
# mae test:   74.80800584870286
# 67
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000778 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4397
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 213.454480
# R2 value train:   0.9598114530413054
# R2 value test:   0.7484143673703765
# RMSE train:   61.830373073570705
# RMSE test:   153.05599693801273
# mae train:   34.530033347757715
# mae test:   80.51459063577126
# 68
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000518 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.358305
# R2 value train:   0.9589966323946033
# R2 value test:   0.7494563790129887
# RMSE train:   62.196558293922145
# RMSE test:   154.2615599296925
# mae train:   34.293771527586664
# mae test:   83.64332570114155
# 69
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000515 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4419
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 214.042547
# R2 value train:   0.9573226932419241
# R2 value test:   0.7904614345845529
# RMSE train:   63.75913994043768
# RMSE test:   139.4381926070874
# mae train:   35.89373967981912
# mae test:   73.46494180996166
# 70
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000546 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4397
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.250883
# R2 value train:   0.9599379219696441
# R2 value test:   0.7695925563414531
# RMSE train:   61.43113621037028
# RMSE test:   148.1955130915637
# mae train:   34.29202919159628
# mae test:   78.44842716062782
# 71
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000536 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4417
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.749899
# R2 value train:   0.9558722166396875
# R2 value test:   0.7839486115545138
# RMSE train:   64.2668432462503
# RMSE test:   144.52926464523688
# mae train:   35.82847731265176
# mae test:   77.61127721968984
# 72
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000561 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4411
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.565042
# R2 value train:   0.9596061940932865
# R2 value test:   0.780059387834119
# RMSE train:   61.609513330837615
# RMSE test:   145.18826889321392
# mae train:   34.50298233634536
# mae test:   77.00302514042907
# 73
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000900 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4408
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.557990
# R2 value train:   0.9568314765456227
# R2 value test:   0.786175816670605
# RMSE train:   63.65820898738788
# RMSE test:   143.32044816442738
# mae train:   35.68345751006716
# mae test:   76.11801104003362
# 74
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000547 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4403
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.073088
# R2 value train:   0.956749403989296
# R2 value test:   0.7805633443451667
# RMSE train:   63.90272265182047
# RMSE test:   144.24237110598415
# mae train:   35.84551197307876
# mae test:   75.32553180363675
# 75
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4392
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.057184
# R2 value train:   0.9593155618878244
# R2 value test:   0.7873578070173857
# RMSE train:   61.801391568685254
# RMSE test:   142.90360997950242
# mae train:   34.52568725114258
# mae test:   75.75586795092661
# 76
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000513 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4406
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.723757
# R2 value train:   0.9581417696304007
# R2 value test:   0.7844052500924219
# RMSE train:   62.80746006260083
# RMSE test:   143.27068052704095
# mae train:   35.239813243337416
# mae test:   75.01268102977386
# 77
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000769 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4396
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.265994
# R2 value train:   0.9557108410189736
# R2 value test:   0.7903881238294578
# RMSE train:   64.4373623408245
# RMSE test:   142.07933700276894
# mae train:   35.971157643383066
# mae test:   74.78966012059792
# 78
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000745 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4401
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.035131
# R2 value train:   0.9583475111651159
# R2 value test:   0.7805583258586074
# RMSE train:   62.811728653336296
# RMSE test:   143.69813704776982
# mae train:   35.57966989918056
# mae test:   75.4729300299244
# 79
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000839 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4399
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.327737
# R2 value train:   0.9562747090826818
# R2 value test:   0.7660257062704487
# RMSE train:   64.50129040756958
# RMSE test:   147.5854643335481
# mae train:   36.177756346977745
# mae test:   77.92780836551825
# 80
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000514 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4455
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.004968
# R2 value train:   0.959287082482871
# R2 value test:   0.7630509828719753
# RMSE train:   61.892414238117
# RMSE test:   150.4621139481698
# mae train:   34.276038155858856
# mae test:   79.1022280465395
# 81
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000783 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4404
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.141480
# R2 value train:   0.95831284344387
# R2 value test:   0.7704991701760421
# RMSE train:   62.8272647329667
# RMSE test:   147.01940943201245
# mae train:   35.03707730524946
# mae test:   77.54898087976275
# 82
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000657 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4414
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.620098
# R2 value train:   0.958570361055032
# R2 value test:   0.7813468690263361
# RMSE train:   62.76005997908598
# RMSE test:   142.8030247886457
# mae train:   35.30611809389948
# mae test:   75.73540947844279
# 83
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000860 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 213.559684
# R2 value train:   0.9587251611149905
# R2 value test:   0.7747224595333954
# RMSE train:   62.88977293691293
# RMSE test:   143.55843813655784
# mae train:   35.23015501886256
# mae test:   76.03827483132758
# 84
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000552 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4396
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.793229
# R2 value train:   0.9581760970614408
# R2 value test:   0.7735606471780069
# RMSE train:   62.82053787055608
# RMSE test:   146.599641941867
# mae train:   35.00792046497868
# mae test:   76.31996492912053
# 85
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000904 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4401
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 206.578627
# R2 value train:   0.959022676165033
# R2 value test:   0.7866558750290521
# RMSE train:   61.92894707251483
# RMSE test:   143.54223123386416
# mae train:   35.06692977459263
# mae test:   76.63369736680907
# 86
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000529 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4398
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 213.048824
# R2 value train:   0.9558356905986944
# R2 value test:   0.7960264160159735
# RMSE train:   64.66973259278004
# RMSE test:   138.56589518657483
# mae train:   35.632817034901606
# mae test:   72.04494310943527
# 87
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000843 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4416
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 213.950733
# R2 value train:   0.959331669821779
# R2 value test:   0.7593926393590816
# RMSE train:   62.31471887241879
# ...
# mae train:   35.8329927742181
# mae test:   74.90792158523232
# 1972
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000650 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4414
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.651762
# R2 value train:   0.9551549595441922
# R2 value test:   0.7976203678625009
# RMSE train:   64.88653723271777
# RMSE test:   139.4143254212522
# mae train:   35.91966707671735
# mae test:   73.86799319392513
# 1973
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000751 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4461
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.159646
# R2 value train:   0.9587248436447507
# R2 value test:   0.760946826251242
# RMSE train:   62.478555030406326
# RMSE test:   150.25124412035453
# mae train:   34.80061938032179
# mae test:   78.55941037441653
# 1974
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000712 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.786422
# R2 value train:   0.9576171361995865
# R2 value test:   0.7860538493775074
# RMSE train:   63.37912697655989
# RMSE test:   141.77594458422058
# mae train:   35.4317294403986
# mae test:   76.14693721735695
# 1975
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000778 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4407
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 206.028094
# R2 value train:   0.9577066437834436
# R2 value test:   0.7760158128649857
# RMSE train:   62.71778581160826
# RMSE test:   148.08695408343374
# mae train:   34.5287634846706
# mae test:   79.79320170923049
# 1976
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000662 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4393
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.957923
# R2 value train:   0.9587878588245172
# R2 value test:   0.7756366810305828
# RMSE train:   62.18185720113382
# RMSE test:   146.90842756316124
# mae train:   34.776151886045206
# mae test:   78.04066630956586
# 1977
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001055 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4426
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.077523
# R2 value train:   0.95850302561215
# R2 value test:   0.7597025735449329
# RMSE train:   62.806118223434574
# RMSE test:   149.74714267911338
# mae train:   34.81172858215511
# mae test:   79.55701751304387
# 1978
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000765 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4442
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.439049
# R2 value train:   0.9559709177088372
# R2 value test:   0.8006958942842772
# RMSE train:   64.52558012218255
# RMSE test:   137.21460676866576
# mae train:   36.09299895327523
# mae test:   73.86906390862872
# 1979
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000829 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4393
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.352228
# R2 value train:   0.9583137126712098
# R2 value test:   0.7812155041146024
# RMSE train:   62.61211078545247
# RMSE test:   144.60749249458786
# mae train:   35.04279625916383
# mae test:   77.33484647139908
# 1980
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000794 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4459
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.546842
# R2 value train:   0.9583707945562615
# R2 value test:   0.7773689392750676
# RMSE train:   62.47061846930613
# RMSE test:   146.46735461955922
# mae train:   34.74501937455681
# mae test:   75.7963358711208
# 1981
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000773 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.755473
# R2 value train:   0.9571818891325123
# R2 value test:   0.7828060048695054
# RMSE train:   63.70187492864252
# RMSE test:   142.87464303633843
# mae train:   35.259863737525535
# mae test:   76.04849709062792
# 1982
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000620 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4453
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.868952
# R2 value train:   0.9574305115197443
# R2 value test:   0.7705045524241144
# RMSE train:   63.56744181504789
# RMSE test:   146.56935987705052
# mae train:   36.0181907051502
# mae test:   77.64675211657585
# 1983
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000638 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4406
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.112455
# R2 value train:   0.9588431902228427
# R2 value test:   0.7700528593917596
# RMSE train:   62.398314277854965
# RMSE test:   147.31053300381495
# mae train:   34.86282272922867
# mae test:   76.16445688284355
# 1984
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000683 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4402
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.897301
# R2 value train:   0.9585635968012856
# R2 value test:   0.7722274856312703
# RMSE train:   62.355558802276526
# RMSE test:   147.9419211856963
# mae train:   34.04470504982604
# mae test:   79.4816402654461
# 1985
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000697 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4403
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.258317
# R2 value train:   0.9600747362305961
# R2 value test:   0.7671845848812442
# RMSE train:   61.057064368319054
# RMSE test:   150.38046751853022
# mae train:   34.284573836376765
# mae test:   79.4887451688742
# 1986
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006076 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4399
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 210.859004
# R2 value train:   0.9589118395047869
# R2 value test:   0.778284897045889
# RMSE train:   62.367616681543105
# RMSE test:   144.53992603782538
# mae train:   34.68517213858142
# mae test:   76.03333210759641
# 1987
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000787 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4410
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.990855
# R2 value train:   0.9586269679940945
# R2 value test:   0.7785291798790561
# RMSE train:   62.420584461677336
# RMSE test:   145.28155335465723
# mae train:   34.81438106869991
# mae test:   77.53343422305998
# 1988
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000781 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.474692
# R2 value train:   0.9592807808129117
# R2 value test:   0.7639781817615752
# RMSE train:   61.969555474861615
# RMSE test:   149.7739882855916
# mae train:   34.210013722745536
# mae test:   78.75095799246711
# 1989
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000670 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4402
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.093705
# R2 value train:   0.9571979569705132
# R2 value test:   0.7928751469008342
# RMSE train:   63.34786427992865
# RMSE test:   141.24859323961562
# mae train:   35.72021526116085
# mae test:   75.76046874332582
# 1990
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000650 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4394
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.656925
# R2 value train:   0.9580150770318582
# R2 value test:   0.799677455808431
# RMSE train:   62.86387193352189
# RMSE test:   138.2757368532443
# mae train:   35.41175717312243
# mae test:   73.50760842934683
# 1991
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001200 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4389
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 215.354623
# R2 value train:   0.9587307093658782
# R2 value test:   0.7626332465803897
# RMSE train:   62.94960192272863
# RMSE test:   146.91630710757417
# mae train:   35.531247317062565
# mae test:   78.09500907372771
# 1992
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000816 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4464
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.434697
# R2 value train:   0.9603214698944316
# R2 value test:   0.7603719489317984
# RMSE train:   61.0926608112793
# RMSE test:   151.3418753448549
# mae train:   34.01028116217184
# mae test:   80.6073826754856
# 1993
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000711 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4390
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 214.420025
# R2 value train:   0.9595175553920507
# R2 value test:   0.7697836773778404
# RMSE train:   62.223958143470504
# RMSE test:   145.42913612783175
# mae train:   34.81767472960371
# mae test:   75.54978850673035
# 1994
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4388
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 215.508358
# R2 value train:   0.9592606006699937
# R2 value test:   0.7628152523125207
# RMSE train:   62.485919653229146
# RMSE test:   147.18788048455653
# mae train:   35.01800487250389
# mae test:   76.6942079363045
# 1995
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4400
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 209.161190
# R2 value train:   0.9563215337524029
# R2 value test:   0.7982822803984466
# RMSE train:   64.08602754202948
# RMSE test:   138.93373047035894
# mae train:   36.00598218733592
# mae test:   73.45241804139712
# 1996
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4394
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 212.318734
# R2 value train:   0.9567275913696756
# R2 value test:   0.7568602086140782
# RMSE train:   64.30514308183633
# RMSE test:   149.67006785386167
# mae train:   35.386394067742
# mae test:   79.74240889037999
# 1997
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000738 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4404
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 207.027264
# R2 value train:   0.9561714460806201
# R2 value test:   0.7868408136592642
# RMSE train:   64.03571266332885
# RMSE test:   143.5604885564405
# mae train:   35.634997433593206
# mae test:   76.71680295648376
# 1998
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001332 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4405
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 214.338369
# R2 value train:   0.958145255479617
# R2 value test:   0.7937737449266726
# RMSE train:   63.218288012011534
# RMSE test:   137.91839456861163
# mae train:   35.83885220666345
# mae test:   71.9932300815356
# 1999
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000684 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4399
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 211.172137
# R2 value train:   0.9588865441838061
# R2 value test:   0.7693166960844935
# RMSE train:   62.4509048240451
# RMSE test:   147.07885781021636
# mae train:   34.59101814368789
# mae test:   77.65650875955956
# 2000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000746 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4404
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 208.358923
# R2 value train:   0.9586809977926448
# R2 value test:   0.777170653164885
# RMSE train:   62.29047185068068
# RMSE test:   146.21900934260498
# mae train:   34.46008947977283
# mae test:   78.40959632584608

# %%
minrmsetest = min(rmsetest)  
ind = rmsetest.index(minrmsetest)  
avg_rmse_train = np.mean(rmsetrain)
avg_rmse_test = np.mean(rmsetest)
avg_r2_train = np.mean(R2train)
avg_r2_test = np.mean(R2test)
avg_mae_train = np.mean(maetrain)
avg_mae_test = np.mean(maetest)
print("Random state is = ", start+ind)
print("Best R2 train/test =  ", R2train[ind]," / ", R2test[ind])
print("Best RMSE train/test = ", rmsetrain[ind]," / ",rmsetest[ind])
print("Best MAE train/test = ", maetrain[ind]," / ",maetest[ind])
print("Avg R2 train/test =  ", avg_r2_train," / ", avg_r2_test)
print("Avg RMSE train/test = ", avg_rmse_train," / ",avg_rmse_test)
print("Avg MAE train/test = ", avg_mae_train," / ",avg_mae_test)
# Out:
# Random state is =  1034
# Best R2 train/test =   0.9541016052543156  /  0.8214331009761602
# Best RMSE train/test =  66.01327132632636  /  129.24520308609306
# Best MAE train/test =  37.009344036247846  /  68.76673422153131
# Avg R2 train/test =   0.9576759299396991  /  0.7793969772090376
# Avg RMSE train/test =  63.230169956976226  /  144.35850199478529
# Avg MAE train/test =  35.3440186574131  /  76.42526719892595

# %%
###### =============================================================================
######         Writing to a file
###### =============================================================================
f = open('regression/best_lbgm_model_using_optuna_optimized_hyperparmeters_SP_NOBANDGAP.txt', 'a')
f.write("No of data points = %d\n" %(len(data)))
f.write("features used = %s\n" %(X.columns))
f.write("No of features = %d\n" %(len(X.columns)))
f.write("Best random state = %d\n" %(ind))
f.write("Model used = %s\n" %(reg.params))
f.write("test size in ratio = %f\n" %(test_size))
f.write("Random state is = %d\n" %(start+ind))
f.write("Best R2 train/test =  %f / %f\n" %(R2train[ind], R2test[ind]))
f.write("Best RMSE train/test = %f / %f\n" %(rmsetrain[ind], rmsetest[ind]))
f.write("Best MAE train/test = %f / %f\n" %(maetrain[ind], maetest[ind]))
f.write("Avg R2 train/test =  %f / %f\n" %(avg_r2_train, avg_r2_test))
f.write("Avg RMSE train/test = %f / %f\n" %(avg_rmse_train, avg_rmse_test))
f.write("Avg MAE train/test = %f / %f\n" %(avg_mae_train, avg_mae_test))
f.write("\n")
f.close()

# %%
## Redo the above step for the best model
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size, random_state = ind)
d_train = lgb.Dataset(X_train, label = Y_train)
reg = lgb.train(params, d_train)
Y_pred_test = reg.predict(X_test) 
Y_pred_train = reg.predict(X_train) 
reg.save_model('regression/best_model_lgbm_SP_NOBANDGAP.txt') ## also save the best model, can be later read directly from this file
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000760 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4413
# [LightGBM] [Info] Number of data points in the train set: 4749, number of used features: 25
# [LightGBM] [Info] Start training from score 213.295905

# %% [markdown]
# ## Parity plot

# %%
from matplotlib import rcParams
xl = np.arange(0,1200,1)
yl = np.arange(0,1200,1)
#plt.rc("savefig", bbox="tight", dpi=2000, figsize=(10,10))
plt.plot(yl, xl, linestyle='dashed', linewidth=1.0, color='black')  
plt.grid(color='black', linestyle='-', linewidth=0.5)
#plt1= plt.figure(figsize=(10,10))
plt.tick_params(axis='both', direction='in')
plt.xlabel('DFT P-Seebeck',fontsize=13)
plt.ylabel('ML Predicted P-Seebeck',fontsize=13)
rcParams['figure.figsize'] = 10,10
sns.scatterplot(x = Y_train, y = Y_pred_train, color = "blue",legend = True, label='Train $R^2 =  0.9541, RMSE = 66.0132, MAE = 37.0093$')
sns.scatterplot(x = Y_test, y = Y_pred_test, color = "silver", legend = True,label='Test $R^2 =  0.8214, RMSE = 129.2452, MAE = 68.7667$')

plt.savefig('images/best_lbgm_optuna_modelnobandgap.png',dpi=2000)
plt.show()

# %% [markdown]
# ## Here we read the save lgbm model to predict an entire new dataset

# %%
import lightgbm as lgb
bst = lgb.Booster(model_file="saved_models/best_model_lgbm_SP_NOBANDGAP.txt")


# Get the model's features in the correct order
cols = bst.feature_name()     # -> ['feat1', 'feat2', 'feat3', ...]

# Use col to reindex the prediction DataFrame
df = X.reindex(columns=cols) # -> df now has the same col ordering as the model

# Get predictions that are consistent! 
predictions = bst.predict(df)
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# d:\Research_works\Postdoc\Project002\ML\final\discovery_2_elements\003_best_ML_model_LGBMnobandgap.ipynb Cell 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Research_works/Postdoc/Project002/ML/final/discovery_2_elements/003_best_ML_model_LGBMnobandgap.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> import lightgbm as lgb
# ----> <a href='vscode-notebook-cell:/d%3A/Research_works/Postdoc/Project002/ML/final/discovery_2_elements/003_best_ML_model_LGBMnobandgap.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> bst = lgb.Booster(model_file="saved_models/best_model_lgbm_SP_NOBANDGAP.txt")
#       <a href='vscode-notebook-cell:/d%3A/Research_works/Postdoc/Project002/ML/final/discovery_2_elements/003_best_ML_model_LGBMnobandgap.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> # Get the model's features in the correct order
#       <a href='vscode-notebook-cell:/d%3A/Research_works/Postdoc/Project002/ML/final/discovery_2_elements/003_best_ML_model_LGBMnobandgap.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> cols = bst.feature_name()     # -> ['feat1', 'feat2', 'feat3', ...]
#
# File c:\Users\ThinkPad\anaconda3\envs\pycaret\lib\site-packages\lightgbm\basic.py:2639, in Booster.__init__(self, params, train_set, model_file, model_str, silent)
#    2637 out_num_iterations = ctypes.c_int(0)
#    2638 self.handle = ctypes.c_void_p()
# -> 2639 _safe_call(_LIB.LGBM_BoosterCreateFromModelfile(
#    2640     c_str(str(model_file)),
#    2641     ctypes.byref(out_num_iterations),
#    2642     ctypes.byref(self.handle)))
#    2643 out_num_class = ctypes.c_int(0)
#    2644 _safe_call(_LIB.LGBM_BoosterGetNumClasses(
#    2645     self.handle,
#    2646     ctypes.byref(out_num_class)))
#
# File c:\Users\ThinkPad\anaconda3\envs\pycaret\lib\site-packages\lightgbm\basic.py:125, in _safe_call(ret)
#     117 """Check the return value from C API call.
#     118
#     119 Parameters
#    (...)
#     122     The return value from C API calls.
#     123 """
#     124 if ret != 0:
# --> 125     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
#
# LightGBMError: Could not open saved_models/best_model_lgbm_SP_NOBANDGAP.txt

# %%
predictions

# %%
df1= pd.DataFrame(predictions)
df1

# %%
X
